# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import missingno as msno 
import re

# %%
# !pip install missingno

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
colnames=['Nofactura', 'ClaseFactura', 'DesClaseFactura', 'FacturaAnulada','FechaFactura','HoraFactura','Material'
          ,'DesMaterial','GrupoArticulo','DesGrArticulo','TipoMaterial','DesTipoMaterial','GrupoMateriales','DescGrupoMateriales',
          'Categoria','DesCategoria','ClaseMaterial','DesClaseMaterial','Topologia','DesTopologia','Color','DesColor','CompradoProducido',
          'DesCompradoProducido','CantFacturada','UMB','ValorNeto','ValorToral','ValCostoTotalPos','ValCostoUnitario','Descuento','IVA',
          'FletePosicion','PosComboPadre','Centro','Almacen','OrgVta','Canal','ZonaVenta','DesZonaVtas','Solicitante','NombreSolicitante','Pagador',
         'NombrePagador','Pais','Ciudad','EdadProducto','Recompra','DiasNoCompra','MaterialNuevo','CondicionPago','DesCondicionPago','OficVentas',
         'GrVendedor','DescGrpoVendedor','NombreVendedorPDP','CEBE','AnoMes','CodGerencia','DesGerencia','LPrecio','NoPedidoCliente','Ped_NoPedOrig','Ped_Fecha',
         'Ped_NoPosOrig','HoraPedido','Entrega','FechaEntrega','HoraEntrega','DocModelo','Fechaproceso'] 
df=pd.read_csv("Facturacion Total Encriptada.csv",sep = ';',nrows=10000, names=colnames)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (52,60) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# df=pd.read_csv("sales10000.csv")

# %%
df.head()
# Out:
#   Nofactura ClaseFactura       DesClaseFactura FacturaAnulada FechaFactura  \
# 0  87091560         ZBRE      Dev Material  II            NaN   24.04.2020
# 1  95287262          YBV           Factura PDP            NaN   14.02.2019
# 2  87074963           G2                 Abono            NaN   07.12.2018
# 3  95165041          YBV           Factura PDP            NaN   28.09.2016
# 4  95002230          YBV  Factura PDP                       X   06.08.2010
#
#    HoraFactura  Material    DesMaterial GrupoArticulo         DesGrArticulo  \
# 0     171640.0      4547  MATERIAL 4547         YBS03  Grupo Articulo YBS03
# 1          NaN      1024  MATERIAL 1024         YBS04  Grupo Articulo YBS04
# 2          NaN      1790  MATERIAL 1790         YBS04  Grupo Articulo YBS04
# 3          NaN      2101  MATERIAL 2101         YBS08  Grupo Articulo YBS08
# 4          NaN      2710  MATERIAL 2710         YBT05  Grupo Articulo YBT05
#
#   TipoMaterial     DesTipoMaterial  GrupoMateriales DescGrupoMateriales  \
# 0         YRVP  Tipo Material YRVP                0   Grupo Material 00
# 1         YRVP  Tipo Material YRVP                0   Grupo Material 00
# 2         YRVP  Tipo Material YRVP                0   Grupo Material 00
# 3         YRVS  Tipo Material YRVS                0   Grupo Material 00
# 4         YPSP  Tipo Material YPSP                3   Grupo Material 03
#
#    Categoria   DesCategoria  ClaseMaterial   DesClaseMaterial  Topologia  \
# 0        502  Categoria 502              1  Clase Material 01        362
# 1        501  Categoria 501              4  Clase Material 04        365
# 2        501  Categoria 501              4  Clase Material 04        361
# 3        501  Categoria 501              3  Clase Material 03         12
# 4        508  Categoria 508              0  Clase Material 00        154
#
#     DesTopologia  Color          DesColor  CompradoProducido  \
# 0  Topologia 362    107  Margen Color 107                 10
# 1  Topologia 365    105  Margen Color 105                 10
# 2  Topologia 361    105  Margen Color 105                 10
# 3  Topologia 012    107  Margen Color 107                 10
# 4  Topologia 154     11   Margen Color 11                 10
#
#     DesCompradoProducido  CantFacturada  UMB  ValorNeto  ValorToral  \
# 0   CompradoProducido 10        -211.68   M2 -2600489.0  -2600489.0
# 1   CompradoProducido 10           1.44   M2    33640.0     33640.0
# 2   CompradoProducido 10          -0.54   M2    -8862.0     -8862.0
# 3   CompradoProducido 10           4.06   M2    47490.0     47490.0
# 4  CompradoProducido 10            1.00  UN     28383.0     32254.0
#
#    ValCostoTotalPos  ValCostoUnitario  Descuento       IVA  FletePosicion  \
# 0       -1833734.79           8662.77        0.0 -494093.0            NaN
# 1          12182.00           8459.72        0.0    6392.0            NaN
# 2              0.00              0.00        0.0   -1684.0            NaN
# 3          26828.00           6607.88        0.0    7598.0            NaN
# 4          22773.00          22773.00    -3871.0    4541.0            NaN
#
#   PosComboPadre  Centro Almacen  OrgVta  Canal  ZonaVenta        DesZonaVtas  \
# 0           NaN    1000    1030    2000     10        205  Zona de Venta 205
# 1           NaN    1400    1404    2000     60        410  Zona de Venta 410
# 2           NaN    1000    1030    1000     10        203  Zona de Venta 203
# 3           NaN    1400    1407    1000     60        409  Zona de Venta 409
# 4                  1400    1402    1000     60        403  Zona de Venta 403
#
#    Solicitante          NombreSolicitante  Pagador          NombrePagador  \
# 0        69186  Persona Solicitante 69186    51942  Persona Pagador 51942
# 1        79647  Persona Solicitante 79647    36248  Persona Pagador 36248
# 2        48848  Persona Solicitante 48848    75893  Persona Pagador 75893
# 3        22845  Persona Solicitante 22845    54586  Persona Pagador 54586
# 4        82934  Persona Solicitante 82934    71584  Persona Pagador 71584
#
#   Pais                     Ciudad EdadProducto  Recompra  DiasNoCompra  \
# 0   CO                    BOGOTÃ        Linea       NaN           NaN
# 1   CO               BARRANQUILLA        Linea       1.0          14.0
# 2   CO                     ZARZAL        Linea       NaN           NaN
# 3   CO                    CÃšCUTA        Linea       0.0           0.0
# 4  CO   Bucaramanga                      Nuevo       0.0           0.0
#
#   MaterialNuevo CondicionPago    DesCondicionPago OficVentas GrVendedor  \
# 0            NO           NaN  Condicion de Pago         100         B1
# 1           NaN           NaN  Condicion de Pago         140         00
# 2           NaN           NaN  Condicion de Pago         100         A7
# 3           NaN           NaN  Condicion de Pago         170        NaN
# 4           NaN           NaN  Condicion de Pago        120
#
#        DescGrpoVendedor NombreVendedorPDP        CEBE  AnoMes  CodGerencia  \
# 0  JONATHAN RODRIGUEZ G               NaN      C31010  202004            1
# 1                   NaN  JUAN MARTINEZ A.      C31010  201902            3
# 2   JORGE H. RAMIREZ G.               NaN      C31010  201812            1
# 3                   NaN               NaN      C31010  201609            3
# 4                                     NaN  C32010      201008            3
#
#              DesGerencia LPrecio NoPedidoCliente Ped_NoPedOrig   Ped_Fecha  \
# 0  Codigo de Gerencia 01      72             NaN           NaN  01.01.1900
# 1  Codigo de Gerencia 03     NaN          BA2151    0022785137  14.02.2019
# 2  Codigo de Gerencia 01      72             NaN           NaN  01.01.1900
# 3  Codigo de Gerencia 03     NaN             NaN    0022662982  30.09.2016
# 4  Codigo de Gerencia 03     NaN             NaN                01.01.1900
#
#    Ped_NoPosOrig  HoraPedido  Entrega FechaEntrega  HoraEntrega DocModelo  \
# 0            0.0         0.0      NaN   01.01.1900          0.0  EP013991
# 1        21800.0         NaN      NaN          NaN          NaN       NaN
# 2            0.0         NaN      NaN          NaN          NaN   P012131
# 3        19900.0         NaN      NaN          NaN          NaN       NaN
# 4            0.0         NaN      NaN          NaN          NaN       NaN
#
#               Fechaproceso
# 0  2020-04-25 02:00:28.950
# 1  2019-02-15 02:00:56.590
# 2  2018-12-08 02:00:33.577
# 3  2016-10-01 02:00:55.560
# 4  2010-08-07 02:00:00.000

# %%
# df.Solicitante.unique()

# %%
# msno.matrix(df)

# %%
df['DATE'] = pd.to_datetime(df['FechaFactura']).dt.to_period('M')

# %%
sales_month =df.groupby('DATE')['Nofactura'].count().plot(title='number of accidents per month')
sales_month.set_xlabel("time in months")
sales_month.set_ylabel("number of sales")
# Out:
# Text(0, 0.5, 'number of sales')

# %%
df['Ciudad'] = df.Ciudad.str.replace('[^A-Za-z\s]+', '').str.lower()
df['Ciudad'] = df['Ciudad'].str.strip()

# %%
df['Ciudad']  = df["Ciudad"].replace({'bogot': "bogota", "ccuta": "cucuta", "medelln": "medellin", "bogota dc": "bogota", "quibd": "quibdo",
                            "montera": "monteria","facatativ": "facatativa","chigorod": "chigoroda","acacas": "acacias","fundacin": "fundacion",
                            "cajic": "cajica","ocaa": "ocaña","ibagu": "ibague","fusagasug": "fusagasuga","barranquilla br prado": "barranquilla",
                            "vlez": "velez","tib": "tibu","garzn": "garzon","magangu": "magangue","bello antioquia": "bello",
                             "cinaga": "cienaga","chiquinquir": "chiquinquira","popayn": "popayan","sutamarchn": "sutamarchan","montelbano": "montelibano",
                             "jeric": "jerico","apartad": "apartado","chocont": "choconta","amag": "amaga","barranquilla br granadill": "barranquilla","barranquilla br alameda d": "barranquilla","girn": "giron",
                             "barranquilla atlantico": "barranquilla","barranquilla br villas de": "barranquilla","barranquilla br las delic": "barranquilla","barranquilla br adelita d": "barranquilla",
                            "barranquilla br el silenc": "barranquilla","barranquilla los alpes": "barranquilla","barranquilla br ciudad ja": "barranquilla",'los teques  caracas' : 'caracas'
                            })

# %%
prueba = df.groupby('Ciudad').size().reset_index(name='count').sort_values(by=['count'], ascending=False)
prueba.head(10)
# Out:
#            Ciudad  count
# 58         cucuta   2154
# 24         bogota   1415
# 26    bucaramanga    843
# 136       pereira    835
# 17   barranquilla    538
# 33           cali    489
# 117      medellin    445
# 37      cartagena    216
# 126         neiva    188
# 190        soacha    136

# %%
df2
# Out:
#   Nofactura ClaseFactura       DesClaseFactura FacturaAnulada FechaFactura  \
# 0  87091560         ZBRE      Dev Material  II            NaN   24.04.2020
# 1  95287262          YBV           Factura PDP            NaN   14.02.2019
# 2  87074963           G2                 Abono            NaN   07.12.2018
# 3  95165041          YBV           Factura PDP            NaN   28.09.2016
# 4  95002230          YBV  Factura PDP                       X   06.08.2010
#
#    HoraFactura  Material    DesMaterial GrupoArticulo         DesGrArticulo  \
# 0     171640.0      4547  MATERIAL 4547         YBS03  Grupo Articulo YBS03
# 1          NaN      1024  MATERIAL 1024         YBS04  Grupo Articulo YBS04
# 2          NaN      1790  MATERIAL 1790         YBS04  Grupo Articulo YBS04
# 3          NaN      2101  MATERIAL 2101         YBS08  Grupo Articulo YBS08
# 4          NaN      2710  MATERIAL 2710         YBT05  Grupo Articulo YBT05
#
#   TipoMaterial     DesTipoMaterial  GrupoMateriales DescGrupoMateriales  \
# 0         YRVP  Tipo Material YRVP                0   Grupo Material 00
# 1         YRVP  Tipo Material YRVP                0   Grupo Material 00
# 2         YRVP  Tipo Material YRVP                0   Grupo Material 00
# 3         YRVS  Tipo Material YRVS                0   Grupo Material 00
# 4         YPSP  Tipo Material YPSP                3   Grupo Material 03
#
#    Categoria   DesCategoria  ClaseMaterial   DesClaseMaterial  Topologia  \
# 0        502  Categoria 502              1  Clase Material 01        362
# 1        501  Categoria 501              4  Clase Material 04        365
# 2        501  Categoria 501              4  Clase Material 04        361
# 3        501  Categoria 501              3  Clase Material 03         12
# 4        508  Categoria 508              0  Clase Material 00        154
#
#     DesTopologia  Color          DesColor  CompradoProducido  \
# 0  Topologia 362    107  Margen Color 107                 10
# 1  Topologia 365    105  Margen Color 105                 10
# 2  Topologia 361    105  Margen Color 105                 10
# 3  Topologia 012    107  Margen Color 107                 10
# 4  Topologia 154     11   Margen Color 11                 10
#
#     DesCompradoProducido  CantFacturada  UMB  ValorNeto  ValorToral  \
# 0   CompradoProducido 10        -211.68   M2 -2600489.0  -2600489.0
# 1   CompradoProducido 10           1.44   M2    33640.0     33640.0
# 2   CompradoProducido 10          -0.54   M2    -8862.0     -8862.0
# 3   CompradoProducido 10           4.06   M2    47490.0     47490.0
# 4  CompradoProducido 10            1.00  UN     28383.0     32254.0
#
#    ValCostoTotalPos  ValCostoUnitario  Descuento       IVA  FletePosicion  \
# 0       -1833734.79           8662.77        0.0 -494093.0            NaN
# 1          12182.00           8459.72        0.0    6392.0            NaN
# 2              0.00              0.00        0.0   -1684.0            NaN
# 3          26828.00           6607.88        0.0    7598.0            NaN
# 4          22773.00          22773.00    -3871.0    4541.0            NaN
#
#   PosComboPadre  Centro Almacen  OrgVta  Canal  ZonaVenta        DesZonaVtas  \
# 0           NaN    1000    1030    2000     10        205  Zona de Venta 205
# 1           NaN    1400    1404    2000     60        410  Zona de Venta 410
# 2           NaN    1000    1030    1000     10        203  Zona de Venta 203
# 3           NaN    1400    1407    1000     60        409  Zona de Venta 409
# 4                  1400    1402    1000     60        403  Zona de Venta 403
#
#    Solicitante          NombreSolicitante  Pagador          NombrePagador  \
# 0        69186  Persona Solicitante 69186    51942  Persona Pagador 51942
# 1        79647  Persona Solicitante 79647    36248  Persona Pagador 36248
# 2        48848  Persona Solicitante 48848    75893  Persona Pagador 75893
# 3        22845  Persona Solicitante 22845    54586  Persona Pagador 54586
# 4        82934  Persona Solicitante 82934    71584  Persona Pagador 71584
#
#   Pais        Ciudad EdadProducto  Recompra  DiasNoCompra MaterialNuevo  \
# 0   CO        bogota        Linea       NaN           NaN            NO
# 1   CO  barranquilla        Linea       1.0          14.0           NaN
# 2   CO        zarzal        Linea       NaN           NaN           NaN
# 3   CO        cucuta        Linea       0.0           0.0           NaN
# 4  CO    bucaramanga        Nuevo       0.0           0.0           NaN
#
#   CondicionPago    DesCondicionPago OficVentas GrVendedor  \
# 0           NaN  Condicion de Pago         100         B1
# 1           NaN  Condicion de Pago         140         00
# 2           NaN  Condicion de Pago         100         A7
# 3           NaN  Condicion de Pago         170        NaN
# 4           NaN  Condicion de Pago        120
#
#        DescGrpoVendedor NombreVendedorPDP        CEBE  AnoMes  CodGerencia  \
# 0  JONATHAN RODRIGUEZ G               NaN      C31010  202004            1
# 1                   NaN  JUAN MARTINEZ A.      C31010  201902            3
# 2   JORGE H. RAMIREZ G.               NaN      C31010  201812            1
# 3                   NaN               NaN      C31010  201609            3
# 4                                     NaN  C32010      201008            3
#
#              DesGerencia LPrecio NoPedidoCliente Ped_NoPedOrig   Ped_Fecha  \
# 0  Codigo de Gerencia 01      72             NaN           NaN  01.01.1900
# 1  Codigo de Gerencia 03     NaN          BA2151    0022785137  14.02.2019
# 2  Codigo de Gerencia 01      72             NaN           NaN  01.01.1900
# 3  Codigo de Gerencia 03     NaN             NaN    0022662982  30.09.2016
# 4  Codigo de Gerencia 03     NaN             NaN                01.01.1900
#
#    Ped_NoPosOrig  HoraPedido  Entrega FechaEntrega  HoraEntrega DocModelo  \
# 0            0.0         0.0      NaN   01.01.1900          0.0  EP013991
# 1        21800.0         NaN      NaN          NaN          NaN       NaN
# 2            0.0         NaN      NaN          NaN          NaN   P012131
# 3        19900.0         NaN      NaN          NaN          NaN       NaN
# 4            0.0         NaN      NaN          NaN          NaN       NaN
#
#               Fechaproceso     DATE
# 0  2020-04-25 02:00:28.950  2020-04
# 1  2019-02-15 02:00:56.590  2019-02
# 2  2018-12-08 02:00:33.577  2018-07
# 3  2016-10-01 02:00:55.560  2016-09
# 4  2010-08-07 02:00:00.000  2010-06

# %%
import googlemaps
gmaps_key = googlemaps.Client(key = 'AIzaSyAPwkFMBe5msMvKvLad9WLGVCHdMONjxlE')
df2 = df.head()
df2['lat'] = 0
df2['lon'] = 0
df2['dep'] = None
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\David\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\David\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2
# Out:
#   Nofactura ClaseFactura       DesClaseFactura FacturaAnulada FechaFactura  \
# 0  87091560         ZBRE      Dev Material  II            NaN   24.04.2020
# 1  95287262          YBV           Factura PDP            NaN   14.02.2019
# 2  87074963           G2                 Abono            NaN   07.12.2018
# 3  95165041          YBV           Factura PDP            NaN   28.09.2016
# 4  95002230          YBV  Factura PDP                       X   06.08.2010
#
#    HoraFactura  Material    DesMaterial GrupoArticulo         DesGrArticulo  \
# 0     171640.0      4547  MATERIAL 4547         YBS03  Grupo Articulo YBS03
# 1          NaN      1024  MATERIAL 1024         YBS04  Grupo Articulo YBS04
# 2          NaN      1790  MATERIAL 1790         YBS04  Grupo Articulo YBS04
# 3          NaN      2101  MATERIAL 2101         YBS08  Grupo Articulo YBS08
# 4          NaN      2710  MATERIAL 2710         YBT05  Grupo Articulo YBT05
#
#   TipoMaterial     DesTipoMaterial  GrupoMateriales DescGrupoMateriales  \
# 0         YRVP  Tipo Material YRVP                0   Grupo Material 00
# 1         YRVP  Tipo Material YRVP                0   Grupo Material 00
# 2         YRVP  Tipo Material YRVP                0   Grupo Material 00
# 3         YRVS  Tipo Material YRVS                0   Grupo Material 00
# 4         YPSP  Tipo Material YPSP                3   Grupo Material 03
#
#    Categoria   DesCategoria  ClaseMaterial   DesClaseMaterial  Topologia  \
# 0        502  Categoria 502              1  Clase Material 01        362
# 1        501  Categoria 501              4  Clase Material 04        365
# 2        501  Categoria 501              4  Clase Material 04        361
# 3        501  Categoria 501              3  Clase Material 03         12
# 4        508  Categoria 508              0  Clase Material 00        154
#
#     DesTopologia  Color          DesColor  CompradoProducido  \
# 0  Topologia 362    107  Margen Color 107                 10
# 1  Topologia 365    105  Margen Color 105                 10
# 2  Topologia 361    105  Margen Color 105                 10
# 3  Topologia 012    107  Margen Color 107                 10
# 4  Topologia 154     11   Margen Color 11                 10
#
#     DesCompradoProducido  CantFacturada  UMB  ValorNeto  ValorToral  \
# 0   CompradoProducido 10        -211.68   M2 -2600489.0  -2600489.0
# 1   CompradoProducido 10           1.44   M2    33640.0     33640.0
# 2   CompradoProducido 10          -0.54   M2    -8862.0     -8862.0
# 3   CompradoProducido 10           4.06   M2    47490.0     47490.0
# 4  CompradoProducido 10            1.00  UN     28383.0     32254.0
#
#    ValCostoTotalPos  ValCostoUnitario  Descuento       IVA  FletePosicion  \
# 0       -1833734.79           8662.77        0.0 -494093.0            NaN
# 1          12182.00           8459.72        0.0    6392.0            NaN
# 2              0.00              0.00        0.0   -1684.0            NaN
# 3          26828.00           6607.88        0.0    7598.0            NaN
# 4          22773.00          22773.00    -3871.0    4541.0            NaN
#
#   PosComboPadre  Centro Almacen  OrgVta  Canal  ZonaVenta        DesZonaVtas  \
# 0           NaN    1000    1030    2000     10        205  Zona de Venta 205
# 1           NaN    1400    1404    2000     60        410  Zona de Venta 410
# 2           NaN    1000    1030    1000     10        203  Zona de Venta 203
# 3           NaN    1400    1407    1000     60        409  Zona de Venta 409
# 4                  1400    1402    1000     60        403  Zona de Venta 403
#
#    Solicitante          NombreSolicitante  Pagador          NombrePagador  \
# 0        69186  Persona Solicitante 69186    51942  Persona Pagador 51942
# 1        79647  Persona Solicitante 79647    36248  Persona Pagador 36248
# 2        48848  Persona Solicitante 48848    75893  Persona Pagador 75893
# 3        22845  Persona Solicitante 22845    54586  Persona Pagador 54586
# 4        82934  Persona Solicitante 82934    71584  Persona Pagador 71584
#
#   Pais        Ciudad EdadProducto  Recompra  DiasNoCompra MaterialNuevo  \
# 0   CO        bogota        Linea       NaN           NaN            NO
# 1   CO  barranquilla        Linea       1.0          14.0           NaN
# 2   CO        zarzal        Linea       NaN           NaN           NaN
# 3   CO        cucuta        Linea       0.0           0.0           NaN
# 4  CO    bucaramanga        Nuevo       0.0           0.0           NaN
#
#   CondicionPago    DesCondicionPago OficVentas GrVendedor  \
# 0           NaN  Condicion de Pago         100         B1
# 1           NaN  Condicion de Pago         140         00
# 2           NaN  Condicion de Pago         100         A7
# 3           NaN  Condicion de Pago         170        NaN
# 4           NaN  Condicion de Pago        120
#
#        DescGrpoVendedor NombreVendedorPDP        CEBE  AnoMes  CodGerencia  \
# 0  JONATHAN RODRIGUEZ G               NaN      C31010  202004            1
# 1                   NaN  JUAN MARTINEZ A.      C31010  201902            3
# 2   JORGE H. RAMIREZ G.               NaN      C31010  201812            1
# 3                   NaN               NaN      C31010  201609            3
# 4                                     NaN  C32010      201008            3
#
#              DesGerencia LPrecio NoPedidoCliente Ped_NoPedOrig   Ped_Fecha  \
# 0  Codigo de Gerencia 01      72             NaN           NaN  01.01.1900
# 1  Codigo de Gerencia 03     NaN          BA2151    0022785137  14.02.2019
# 2  Codigo de Gerencia 01      72             NaN           NaN  01.01.1900
# 3  Codigo de Gerencia 03     NaN             NaN    0022662982  30.09.2016
# 4  Codigo de Gerencia 03     NaN             NaN                01.01.1900
#
#    Ped_NoPosOrig  HoraPedido  Entrega FechaEntrega  HoraEntrega DocModelo  \
# 0            0.0         0.0      NaN   01.01.1900          0.0  EP013991
# 1        21800.0         NaN      NaN          NaN          NaN       NaN
# 2            0.0         NaN      NaN          NaN          NaN   P012131
# 3        19900.0         NaN      NaN          NaN          NaN       NaN
# 4            0.0         NaN      NaN          NaN          NaN       NaN
#
#               Fechaproceso     DATE  lat  lon   dep
# 0  2020-04-25 02:00:28.950  2020-04    0    0  None
# 1  2019-02-15 02:00:56.590  2019-02    0    0  None
# 2  2018-12-08 02:00:33.577  2018-07    0    0  None
# 3  2016-10-01 02:00:55.560  2016-09    0    0  None
# 4  2010-08-07 02:00:00.000  2010-06    0    0  None

# %%
for i in range(0,len(df2),1):
    try:
        geocode_result = gmaps_key.geocode(df.iat[i,45]) 
        df2.iat[i,df2.columns.get_loc('lat')] = geocode_result[0]["geometry"]["location"]['lat']
        df2.iat[i,df2.columns.get_loc('lon')] = geocode_result[0]["geometry"]["location"]['lng']
        df2.iat[i,df2.columns.get_loc('dep')] = geocode_result[0]['address_components'][2]['long_name']
    except:
        df2.iat[i,df2.columns.get_loc('lat')] = 0
        print('problem')
        df2.iat[i,df2.columns.get_loc('lon')] = 0
        df2.iat[i,df2.columns.get_loc('dep')] = None

# %%
df2
# Out:
#   Nofactura ClaseFactura       DesClaseFactura FacturaAnulada FechaFactura  \
# 0  87091560         ZBRE      Dev Material  II            NaN   24.04.2020
# 1  95287262          YBV           Factura PDP            NaN   14.02.2019
# 2  87074963           G2                 Abono            NaN   07.12.2018
# 3  95165041          YBV           Factura PDP            NaN   28.09.2016
# 4  95002230          YBV  Factura PDP                       X   06.08.2010
#
#    HoraFactura  Material    DesMaterial GrupoArticulo         DesGrArticulo  \
# 0     171640.0      4547  MATERIAL 4547         YBS03  Grupo Articulo YBS03
# 1          NaN      1024  MATERIAL 1024         YBS04  Grupo Articulo YBS04
# 2          NaN      1790  MATERIAL 1790         YBS04  Grupo Articulo YBS04
# 3          NaN      2101  MATERIAL 2101         YBS08  Grupo Articulo YBS08
# 4          NaN      2710  MATERIAL 2710         YBT05  Grupo Articulo YBT05
#
#   TipoMaterial     DesTipoMaterial  GrupoMateriales DescGrupoMateriales  \
# 0         YRVP  Tipo Material YRVP                0   Grupo Material 00
# 1         YRVP  Tipo Material YRVP                0   Grupo Material 00
# 2         YRVP  Tipo Material YRVP                0   Grupo Material 00
# 3         YRVS  Tipo Material YRVS                0   Grupo Material 00
# 4         YPSP  Tipo Material YPSP                3   Grupo Material 03
#
#    Categoria   DesCategoria  ClaseMaterial   DesClaseMaterial  Topologia  \
# 0        502  Categoria 502              1  Clase Material 01        362
# 1        501  Categoria 501              4  Clase Material 04        365
# 2        501  Categoria 501              4  Clase Material 04        361
# 3        501  Categoria 501              3  Clase Material 03         12
# 4        508  Categoria 508              0  Clase Material 00        154
#
#     DesTopologia  Color          DesColor  CompradoProducido  \
# 0  Topologia 362    107  Margen Color 107                 10
# 1  Topologia 365    105  Margen Color 105                 10
# 2  Topologia 361    105  Margen Color 105                 10
# 3  Topologia 012    107  Margen Color 107                 10
# 4  Topologia 154     11   Margen Color 11                 10
#
#     DesCompradoProducido  CantFacturada  UMB  ValorNeto  ValorToral  \
# 0   CompradoProducido 10        -211.68   M2 -2600489.0  -2600489.0
# 1   CompradoProducido 10           1.44   M2    33640.0     33640.0
# 2   CompradoProducido 10          -0.54   M2    -8862.0     -8862.0
# 3   CompradoProducido 10           4.06   M2    47490.0     47490.0
# 4  CompradoProducido 10            1.00  UN     28383.0     32254.0
#
#    ValCostoTotalPos  ValCostoUnitario  Descuento       IVA  FletePosicion  \
# 0       -1833734.79           8662.77        0.0 -494093.0            NaN
# 1          12182.00           8459.72        0.0    6392.0            NaN
# 2              0.00              0.00        0.0   -1684.0            NaN
# 3          26828.00           6607.88        0.0    7598.0            NaN
# 4          22773.00          22773.00    -3871.0    4541.0            NaN
#
#   PosComboPadre  Centro Almacen  OrgVta  Canal  ZonaVenta        DesZonaVtas  \
# 0           NaN    1000    1030    2000     10        205  Zona de Venta 205
# 1           NaN    1400    1404    2000     60        410  Zona de Venta 410
# 2           NaN    1000    1030    1000     10        203  Zona de Venta 203
# 3           NaN    1400    1407    1000     60        409  Zona de Venta 409
# 4                  1400    1402    1000     60        403  Zona de Venta 403
#
#    Solicitante          NombreSolicitante  Pagador          NombrePagador  \
# 0        69186  Persona Solicitante 69186    51942  Persona Pagador 51942
# 1        79647  Persona Solicitante 79647    36248  Persona Pagador 36248
# 2        48848  Persona Solicitante 48848    75893  Persona Pagador 75893
# 3        22845  Persona Solicitante 22845    54586  Persona Pagador 54586
# 4        82934  Persona Solicitante 82934    71584  Persona Pagador 71584
#
#   Pais        Ciudad EdadProducto  Recompra  DiasNoCompra MaterialNuevo  \
# 0   CO        bogota        Linea       NaN           NaN            NO
# 1   CO  barranquilla        Linea       1.0          14.0           NaN
# 2   CO        zarzal        Linea       NaN           NaN           NaN
# 3   CO        cucuta        Linea       0.0           0.0           NaN
# 4  CO    bucaramanga        Nuevo       0.0           0.0           NaN
#
#   CondicionPago    DesCondicionPago OficVentas GrVendedor  \
# 0           NaN  Condicion de Pago         100         B1
# 1           NaN  Condicion de Pago         140         00
# 2           NaN  Condicion de Pago         100         A7
# 3           NaN  Condicion de Pago         170        NaN
# 4           NaN  Condicion de Pago        120
#
#        DescGrpoVendedor NombreVendedorPDP        CEBE  AnoMes  CodGerencia  \
# 0  JONATHAN RODRIGUEZ G               NaN      C31010  202004            1
# 1                   NaN  JUAN MARTINEZ A.      C31010  201902            3
# 2   JORGE H. RAMIREZ G.               NaN      C31010  201812            1
# 3                   NaN               NaN      C31010  201609            3
# 4                                     NaN  C32010      201008            3
#
#              DesGerencia LPrecio NoPedidoCliente Ped_NoPedOrig   Ped_Fecha  \
# 0  Codigo de Gerencia 01      72             NaN           NaN  01.01.1900
# 1  Codigo de Gerencia 03     NaN          BA2151    0022785137  14.02.2019
# 2  Codigo de Gerencia 01      72             NaN           NaN  01.01.1900
# 3  Codigo de Gerencia 03     NaN             NaN    0022662982  30.09.2016
# 4  Codigo de Gerencia 03     NaN             NaN                01.01.1900
#
#    Ped_NoPosOrig  HoraPedido  Entrega FechaEntrega  HoraEntrega DocModelo  \
# 0            0.0         0.0      NaN   01.01.1900          0.0  EP013991
# 1        21800.0         NaN      NaN          NaN          NaN       NaN
# 2            0.0         NaN      NaN          NaN          NaN   P012131
# 3        19900.0         NaN      NaN          NaN          NaN       NaN
# 4            0.0         NaN      NaN          NaN          NaN       NaN
#
#               Fechaproceso     DATE  lat  lon              dep
# 0  2020-04-25 02:00:28.950  2020-04    4  -74     Cundinamarca
# 1  2019-02-15 02:00:56.590  2019-02   11  -74        Atlantico
# 2  2018-12-08 02:00:33.577  2018-07    4  -76  Valle del Cauca
# 3  2016-10-01 02:00:55.560  2016-09    7  -72  North Santander
# 4  2010-08-07 02:00:00.000  2010-06    7  -73        Santander

# %%
from folium.plugins import HeatMap
def generateBaseMap(default_location=[4.710989,-74.072092], default_zoom_start=5):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

# %%
sales = df2.groupby('dep').size().reset_index(name='count')

# %%
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# geocode_result

# %%
# df2.iat[i,df2.columns.get_loc('dep')]

# %%
# geocode_result[0]['address_components'][2]['long_name']

# %%
# geocode_result

# %%
# geocode_result[0]['address_components'][2]['long_name']

# %%
# gapminder_2002 = df2[df2['dep'] == "Colombia"]
# df2.loc[df2.dep == "Colombia", "dep"] = "Cundinamarca"

# %%
# gapminder_2002
